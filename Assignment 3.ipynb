# %%
import numpy as np
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth

# %%
ds = pd.read_csv('Online Retail.csv')

# %%
ds
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12-1-2010 8:26       2.55     17850.0  United Kingdom
# 1        12-1-2010 8:26       3.39     17850.0  United Kingdom
# 2        12-1-2010 8:26       2.75     17850.0  United Kingdom
# 3        12-1-2010 8:26       3.39     17850.0  United Kingdom
# 4        12-1-2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12-9-2011 12:50       0.85     12680.0          France
# 541905  12-9-2011 12:50       2.10     12680.0          France
# 541906  12-9-2011 12:50       4.15     12680.0          France
# 541907  12-9-2011 12:50       4.15     12680.0          France
# 541908  12-9-2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [raw]
# PREPROCESSING STARTS HERE

# %%
#We will explore data from the country of France
ds = ds.query("Country == 'France'")
ds
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 26       12-1-2010 8:45       3.75     12583.0  France
# 27       12-1-2010 8:45       3.75     12583.0  France
# 28       12-1-2010 8:45       3.75     12583.0  France
# 29       12-1-2010 8:45       0.85     12583.0  France
# 30       12-1-2010 8:45       0.65     12583.0  France
# ...                 ...        ...         ...     ...
# 541904  12-9-2011 12:50       0.85     12680.0  France
# 541905  12-9-2011 12:50       2.10     12680.0  France
# 541906  12-9-2011 12:50       4.15     12680.0  France
# 541907  12-9-2011 12:50       4.15     12680.0  France
# 541908  12-9-2011 12:50       4.95     12680.0  France
#
# [8557 rows x 8 columns]

# %%
#No missing and null data on our dataset.
print(ds.isna().sum(), "\n")

print(ds.isnull().sum())
# Out:
# InvoiceNo       0
# StockCode       0
# Description     0
# Quantity        0
# InvoiceDate     0
# UnitPrice       0
# CustomerID     66
# Country         0
# dtype: int64
#
# InvoiceNo       0
# StockCode       0
# Description     0
# Quantity        0
# InvoiceDate     0
# UnitPrice       0
# CustomerID     66
# Country         0
# dtype: int64

# %%
#aggregate transactions based on invoice number because Same Invoice number means that it is within one Transaction
df = ds.groupby(['InvoiceNo'], as_index=False).agg(list)

# %%
df
# Out:
#     InvoiceNo                                          StockCode  \
# 0      536370  [22728, 22727, 22726, 21724, 21883, 10002, 217...
# 1      536852   [22549, 22544, 22539, 22661, 21791, 21786, POST]
# 2      536974  [15056BL, 15056P, 20679, 21915, 22659, 22352, ...
# 3      537065  [22837, 22846, 22892, 22968, 84678, 20665, 217...
# 4      537463  [22961, 21224, 22326, 21124, 21121, 21137, 220...
# ..        ...                                                ...
# 456   C579532                                      [POST, 22890]
# 457   C579562                                     [23084, 21731]
# 458   C580161                                             [POST]
# 459   C580263  [M, M, 70007, 85175, 84821, 84819, 84817, 7258...
# 460   C581316                              [23020, 21531, 23174]
#
#                                            Description  \
# 0    [ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 1    [PICTURE DOMINOES, MINI JIGSAW SPACEBOY, MINI ...
# 2    [EDWARDIAN PARASOL BLACK, EDWARDIAN PARASOL PI...
# 3    [HOT WATER BOTTLE BABUSHKA , BREAD BIN DINER S...
# 4    [JAM MAKING SET PRINTED, SET/4 SKULL BADGES, R...
# ..                                                 ...
# 456      [POSTAGE, NOVELTY BISCUITS CAKE STAND 3 TIER]
# 457  [RABBIT NIGHT LIGHT, RED TOADSTOOL LED NIGHT L...
# 458                                          [POSTAGE]
# 459  [Manual, Manual, HI TEC ALPINE HAND WARMER, CA...
# 460  [GLASS  SONGBIRD STORAGE JAR, RED RETROSPOT SU...
#
#                                               Quantity  \
# 0    [24, 24, 12, 12, 24, 48, 24, 18, 24, 24, 24, 2...
# 1                          [12, 24, 24, 10, 12, 24, 1]
# 2    [9, 3, 6, 12, 12, 12, 12, 12, 2, 2, 12, 6, 10,...
# 3    [8, 1, 12, 8, 6, 6, 24, 24, 6, 2, 12, 24, 12, ...
# 4    [12, 10, 18, 24, 24, 4, 6, 12, 12, 12, 4, 16, ...
# ..                                                 ...
# 456                                           [-1, -4]
# 457                                           [-1, -1]
# 458                                               [-2]
# 459  [-4, -16, -12, -16, -12, -3, -12, -36, -16, -1...
# 460                                       [-1, -1, -1]
#
#                                            InvoiceDate  \
# 0    [12-1-2010 8:45, 12-1-2010 8:45, 12-1-2010 8:4...
# 1    [12-3-2010 9:51, 12-3-2010 9:51, 12-3-2010 9:5...
# 2    [12-3-2010 13:59, 12-3-2010 13:59, 12-3-2010 1...
# 3    [12-5-2010 11:57, 12-5-2010 11:57, 12-5-2010 1...
# 4    [12-7-2010 10:08, 12-7-2010 10:08, 12-7-2010 1...
# ..                                                 ...
# 456                 [11-30-2011 9:21, 11-30-2011 9:21]
# 457               [11-30-2011 11:39, 11-30-2011 11:39]
# 458                                  [12-2-2011 10:49]
# 459  [12-2-2011 12:43, 12-2-2011 12:43, 12-2-2011 1...
# 460  [12-8-2011 11:46, 12-8-2011 11:46, 12-8-2011 1...
#
#                                              UnitPrice  \
# 0    [3.75, 3.75, 3.75, 0.85, 0.65, 0.85, 1.25, 2.9...
# 1           [1.45, 0.42, 0.42, 0.85, 1.25, 0.42, 18.0]
# 2    [5.95, 5.95, 5.95, 1.25, 1.95, 2.55, 1.25, 0.4...
# 3    [4.65, 16.95, 1.25, 8.5, 2.55, 2.95, 0.42, 0.8...
# 4    [1.45, 1.25, 2.95, 1.25, 1.25, 3.75, 2.55, 0.4...
# ..                                                 ...
# 456                                       [18.0, 9.95]
# 457                                       [2.08, 1.65]
# 458                                             [18.0]
# 459  [9.95, 0.29, 1.65, 0.42, 0.85, 4.25, 2.1, 0.42...
# 460                                 [12.5, 2.55, 4.15]
#
#                                             CustomerID  \
# 0    [12583.0, 12583.0, 12583.0, 12583.0, 12583.0, ...
# 1    [12686.0, 12686.0, 12686.0, 12686.0, 12686.0, ...
# 2    [12682.0, 12682.0, 12682.0, 12682.0, 12682.0, ...
# 3    [12567.0, 12567.0, 12567.0, 12567.0, 12567.0, ...
# 4    [12681.0, 12681.0, 12681.0, 12681.0, 12681.0, ...
# ..                                                 ...
# 456                                 [12494.0, 12494.0]
# 457                                 [12553.0, 12553.0]
# 458                                          [12700.0]
# 459  [12536.0, 12536.0, 12536.0, 12536.0, 12536.0, ...
# 460                        [12523.0, 12523.0, 12523.0]
#
#                                                Country
# 0    [France, France, France, France, France, Franc...
# 1    [France, France, France, France, France, Franc...
# 2    [France, France, France, France, France, Franc...
# 3    [France, France, France, France, France, Franc...
# 4    [France, France, France, France, France, Franc...
# ..                                                 ...
# 456                                   [France, France]
# 457                                   [France, France]
# 458                                           [France]
# 459  [France, France, France, France, France, Franc...
# 460                           [France, France, France]
#
# [461 rows x 8 columns]

# %%
#extract only the two columns we are interested in, which are the InvoiceNo and Description.
data = df.iloc[:,[0,2]]

# %%
data
# Out:
#     InvoiceNo                                        Description
# 0      536370  [ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 1      536852  [PICTURE DOMINOES, MINI JIGSAW SPACEBOY, MINI ...
# 2      536974  [EDWARDIAN PARASOL BLACK, EDWARDIAN PARASOL PI...
# 3      537065  [HOT WATER BOTTLE BABUSHKA , BREAD BIN DINER S...
# 4      537463  [JAM MAKING SET PRINTED, SET/4 SKULL BADGES, R...
# ..        ...                                                ...
# 456   C579532      [POSTAGE, NOVELTY BISCUITS CAKE STAND 3 TIER]
# 457   C579562  [RABBIT NIGHT LIGHT, RED TOADSTOOL LED NIGHT L...
# 458   C580161                                          [POSTAGE]
# 459   C580263  [Manual, Manual, HI TEC ALPINE HAND WARMER, CA...
# 460   C581316  [GLASS  SONGBIRD STORAGE JAR, RED RETROSPOT SU...
#
# [461 rows x 2 columns]

# %%
#Removing rows with invoice numbers starting with letter A and C, which indicates "cancelled" and "adjust bad debt". 
data = data[~data.iloc[:,0].str.startswith('C')]
data = data[~data.iloc[:,0].str.startswith('A')]

# %%
data
# Out:
#     InvoiceNo                                        Description
# 0      536370  [ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 1      536852  [PICTURE DOMINOES, MINI JIGSAW SPACEBOY, MINI ...
# 2      536974  [EDWARDIAN PARASOL BLACK, EDWARDIAN PARASOL PI...
# 3      537065  [HOT WATER BOTTLE BABUSHKA , BREAD BIN DINER S...
# 4      537463  [JAM MAKING SET PRINTED, SET/4 SKULL BADGES, R...
# ..        ...                                                ...
# 387    580986  [LARGE RED BABUSHKA NOTEBOOK , SMALL RED BABUS...
# 388    581001  [SET OF 6 RIBBONS PERFECTLY PRETTY  , MINI JIG...
# 389    581171  [TRADITIONAL PICK UP STICKS GAME , GINGERBREAD...
# 390    581279  [CAKE STAND WHITE TWO TIER LACE, REGENCY CAKES...
# 391    581587  [CIRCUS PARADE LUNCH BOX , PLASTERS IN TIN CIR...
#
# [392 rows x 2 columns]

# %%
#Checking if all Invoice No. are integer values with no letters.
pd.to_numeric(data['InvoiceNo'], errors='coerce').notnull().all()
# Out:
# True

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 391
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    392 non-null    object
#  1   Description  392 non-null    object
# dtypes: object(2)
# memory usage: 9.2+ KB

# %%
data.dropna()
# Out:
#     InvoiceNo                                        Description
# 0      536370  [ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 1      536852  [PICTURE DOMINOES, MINI JIGSAW SPACEBOY, MINI ...
# 2      536974  [EDWARDIAN PARASOL BLACK, EDWARDIAN PARASOL PI...
# 3      537065  [HOT WATER BOTTLE BABUSHKA , BREAD BIN DINER S...
# 4      537463  [JAM MAKING SET PRINTED, SET/4 SKULL BADGES, R...
# ..        ...                                                ...
# 387    580986  [LARGE RED BABUSHKA NOTEBOOK , SMALL RED BABUS...
# 388    581001  [SET OF 6 RIBBONS PERFECTLY PRETTY  , MINI JIG...
# 389    581171  [TRADITIONAL PICK UP STICKS GAME , GINGERBREAD...
# 390    581279  [CAKE STAND WHITE TWO TIER LACE, REGENCY CAKES...
# 391    581587  [CIRCUS PARADE LUNCH BOX , PLASTERS IN TIN CIR...
#
# [392 rows x 2 columns]

# %%
data.isna().sum()
# Out:
# InvoiceNo      0
# Description    0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# InvoiceNo      0
# Description    0
# dtype: int64

# %%
data
# Out:
#     InvoiceNo                                        Description
# 0      536370  [ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 1      536852  [PICTURE DOMINOES, MINI JIGSAW SPACEBOY, MINI ...
# 2      536974  [EDWARDIAN PARASOL BLACK, EDWARDIAN PARASOL PI...
# 3      537065  [HOT WATER BOTTLE BABUSHKA , BREAD BIN DINER S...
# 4      537463  [JAM MAKING SET PRINTED, SET/4 SKULL BADGES, R...
# ..        ...                                                ...
# 387    580986  [LARGE RED BABUSHKA NOTEBOOK , SMALL RED BABUS...
# 388    581001  [SET OF 6 RIBBONS PERFECTLY PRETTY  , MINI JIG...
# 389    581171  [TRADITIONAL PICK UP STICKS GAME , GINGERBREAD...
# 390    581279  [CAKE STAND WHITE TWO TIER LACE, REGENCY CAKES...
# 391    581587  [CIRCUS PARADE LUNCH BOX , PLASTERS IN TIN CIR...
#
# [392 rows x 2 columns]

# %%
#converting the Raw data into the format that is needed for the algorithm.
itemset = pd.DataFrame(data.Description.values.tolist()).add_prefix('item_')
itemset
# Out:
#                                   item_0                          item_1  \
# 0              ALARM CLOCK BAKELIKE PINK       ALARM CLOCK BAKELIKE RED
# 1                       PICTURE DOMINOES            MINI JIGSAW SPACEBOY
# 2                EDWARDIAN PARASOL BLACK          EDWARDIAN PARASOL PINK
# 3             HOT WATER BOTTLE BABUSHKA       BREAD BIN DINER STYLE RED
# 4                 JAM MAKING SET PRINTED              SET/4 SKULL BADGES
# ..                                   ...                             ...
# 387         LARGE RED BABUSHKA NOTEBOOK     SMALL RED BABUSHKA NOTEBOOK
# 388  SET OF 6 RIBBONS PERFECTLY PRETTY        MINI JIGSAW CIRCUS PARADE
# 389     TRADITIONAL PICK UP STICKS GAME    GINGERBREAD MAN COOKIE CUTTER
# 390       CAKE STAND WHITE TWO TIER LACE        REGENCY CAKESTAND 3 TIER
# 391             CIRCUS PARADE LUNCH BOX   PLASTERS IN TIN CIRCUS PARADE
#
#                                   item_2                              item_3  \
# 0             ALARM CLOCK BAKELIKE GREEN     PANDA AND BUNNIES STICKER SHEET
# 1                 MINI JIGSAW DOLLY GIRL     CHARLOTTE BAG DOLLY GIRL DESIGN
# 2                  EDWARDIAN PARASOL RED              RED  HARMONICA IN BOX
# 3      SET OF SALT AND PEPPER TOADSTOOLS          ROSE COTTAGE KEEPSAKE BOX
# 4    ROUND SNACK BOXES SET OF4 WOODLAND   SET/10 BLUE POLKADOT PARTY CANDLES
# ..                                   ...                                 ...
# 387     LARGE PURPLE BABUSHKA NOTEBOOK       SMALL PURPLE BABUSHKA NOTEBOOK
# 388                 MINI JIGSAW SPACEBOY      MINI LIGHTS WOODLAND MUSHROOMS
# 389             RED RETROSPOT MINI CASES              RED RETROSPOT UMBRELLA
# 390                              POSTAGE                                None
# 391            PLASTERS IN TIN STRONGMAN           ALARM CLOCK BAKELIKE PINK
#
#                                  item_4                             item_5  \
# 0                      STARS GIFT TAPE         INFLATABLE POLITICAL GLOBE
# 1    VINTAGE HEADS AND TAILS CARD GAME                  POLKADOT RAIN HAT
# 2               LUNCH BOX I LOVE LONDON  LUNCH BOX WITH CUTLERY RETROSPOT
# 3             CLASSICAL ROSE SMALL VASE               RED RETROSPOT PURSE
# 4     SET/10 RED POLKADOT PARTY CANDLES           BLACK RECORD COVER FRAME
# ..                                  ...                                ...
# 387     LARGE YELLOW BABUSHKA NOTEBOOK     SMALL YELLOW BABUSHKA NOTEBOOK
# 388                  RABBIT NIGHT LIGHT                     SPOTTY BUNTING
# 389    RED RETROSPOT CHILDRENS UMBRELLA       PARISIENNE JEWELLERY DRAWER
# 390                                None                               None
# 391           ALARM CLOCK BAKELIKE RED          ALARM CLOCK BAKELIKE GREEN
#
#                                   item_6                           item_7  \
# 0     VINTAGE HEADS AND TAILS CARD GAME   SET/2 RED RETROSPOT TEA TOWELS
# 1                                POSTAGE                             None
# 2      SET OF SALT AND PEPPER TOADSTOOLS          TEA PARTY BIRTHDAY CARD
# 3                     POLKADOT RAIN HAT             RAIN PONCHO RETROSPOT
# 4           RECORD FRAME 7" SINGLE SIZE               ROBOT BIRTHDAY CARD
# ..                                   ...                              ...
# 387         SET 7 BABUSHKA NESTING BOXES   PAPERWEIGHT CHILDHOOD MEMORIES
# 388  SET OF 20 VINTAGE CHRISTMAS NAPKINS      PACK OF 20 SPACEBOY NAPKINS
# 389           FAWN BLUE HOT WATER BOTTLE          TEA PARTY BIRTHDAY CARD
# 390                                 None                             None
# 391           ALARM CLOCK BAKELIKE IVORY  CHILDRENS APRON SPACEBOY DESIGN
#
#                                   item_8                          item_9  ...  \
# 0    ROUND SNACK BOXES SET OF4 WOODLAND              SPACEBOY LUNCH BOX   ...
# 1                                   None                            None  ...
# 2             ASSORTED COLOUR MINI CASES        RED RETROSPOT MINI CASES  ...
# 3               RED RETROSPOT MINI CASES      ASSORTED COLOUR MINI CASES  ...
# 4                TEA PARTY BIRTHDAY CARD      FANCY FONT BIRTHDAY CARD,   ...
# ..                                   ...                             ...  ...
# 387             SKULLS STORAGE BOX LARGE        SKULLS STORAGE BOX SMALL  ...
# 388           BAKING SET SPACEBOY DESIGN  EMBROIDERED RIBBON REEL DAISY   ...
# 389   COWBOYS AND INDIANS BIRTHDAY CARD     PENNY FARTHING BIRTHDAY CARD  ...
# 390                                 None                            None  ...
# 391                  SPACEBOY LUNCH BOX      CHILDRENS CUTLERY SPACEBOY   ...
#
#     item_249 item_250 item_251 item_252 item_253 item_254 item_255 item_256  \
# 0       None     None     None     None     None     None     None     None
# 1       None     None     None     None     None     None     None     None
# 2       None     None     None     None     None     None     None     None
# 3       None     None     None     None     None     None     None     None
# 4       None     None     None     None     None     None     None     None
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 387     None     None     None     None     None     None     None     None
# 388     None     None     None     None     None     None     None     None
# 389     None     None     None     None     None     None     None     None
# 390     None     None     None     None     None     None     None     None
# 391     None     None     None     None     None     None     None     None
#
#     item_257 item_258
# 0       None     None
# 1       None     None
# 2       None     None
# 3       None     None
# 4       None     None
# ..       ...      ...
# 387     None     None
# 388     None     None
# 389     None     None
# 390     None     None
# 391     None     None
#
# [392 rows x 259 columns]

# %%
#creating an array list that contains the transacted items
dataset = []
for i in range(len(itemset)):
    dataset.append(itemset.loc[i].dropna().tolist())

# %%
#Using the Transaction Encoder to transform the data into the format that can be used
#for Assocication Rule Mining Algorithm
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#       50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# 0                             False               False
# 1                             False               False
# 2                             False               False
# 3                             False               False
# 4                             False               False
# ..                              ...                 ...
# 387                           False               False
# 388                           False               False
# 389                           False               False
# 390                           False               False
# 391                           False               False
#
#       I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# 0                           False                     False
# 1                           False                     False
# 2                           False                     False
# 3                           False                     False
# 4                           False                     False
# ..                            ...                       ...
# 387                         False                     False
# 388                         False                     False
# 389                         False                     False
# 390                         False                     False
# 391                         False                     False
#
#       SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# 0                                True                    False
# 1                               False                    False
# 2                               False                    False
# 3                               False                    False
# 4                               False                    False
# ..                                ...                      ...
# 387                             False                    False
# 388                             False                    False
# 389                             False                    False
# 390                             False                    False
# 391                             False                    False
#
#       TRELLIS COAT RACK  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# 0                 False                   False                       False
# 1                 False                   False                       False
# 2                 False                   False                       False
# 3                 False                   False                       False
# 4                 False                   False                       False
# ..                  ...                     ...                         ...
# 387               False                   False                       False
# 388               False                   False                       False
# 389               False                   False                       False
# 390               False                   False                       False
# 391               False                   False                       False
#
#      12 EGG HOUSE PAINTED WOOD  ...  WRAP VINTAGE PETALS  DESIGN  \
# 0                        False  ...                        False
# 1                        False  ...                        False
# 2                        False  ...                        False
# 3                        False  ...                        False
# 4                        False  ...                        False
# ..                         ...  ...                          ...
# 387                      False  ...                        False
# 388                      False  ...                        False
# 389                      False  ...                        False
# 390                      False  ...                        False
# 391                      False  ...                        False
#
#      YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# 0                             False                            False
# 1                             False                            False
# 2                             False                            False
# 3                             False                            False
# 4                             False                            False
# ..                              ...                              ...
# 387                           False                            False
# 388                           False                            False
# 389                           False                            False
# 390                           False                            False
# 391                           False                            False
#
#      YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER   \
# 0                      False                       False
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                      False                       False
# ..                       ...                         ...
# 387                    False                       False
# 388                    False                       False
# 389                    False                       False
# 390                    False                       False
# 391                    False                       False
#
#      ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
# ..                         ...                         ...
# 387                      False                       False
# 388                      False                       False
# 389                      False                       False
# 390                      False                       False
# 391                      False                       False
#
#      ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# 0                          False                           False
# 1                          False                           False
# 2                          False                           False
# 3                          False                           False
# 4                          False                           False
# ..                           ...                             ...
# 387                        False                           False
# 388                        False                           False
# 389                        False                           False
# 390                        False                           False
# 391                        False                           False
#
#      ZINC T-LIGHT HOLDER STARS SMALL
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
# ..                               ...
# 387                            False
# 388                            False
# 389                            False
# 390                            False
# 391                            False
#
# [392 rows x 1564 columns]

# %%
#Determine the Frequent_itemset which will be used to determine the Association Rules of the transactions. 
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)
frequent_itemsets
# Out:
#         support                                           itemsets
# 0      0.022959                               ( DOLLY GIRL BEAKER)
# 1      0.012755                     ( I LOVE LONDON MINI BACKPACK)
# 2      0.017857                 ( SET 2 TEA TOWELS I LOVE LONDON )
# 3      0.040816                          ( SPACEBOY BABY GIFT SET)
# 4      0.030612                           (10 COLOUR SPACEBOY PEN)
# ...         ...                                                ...
# 39622  0.010204  (ROUND SNACK BOXES SET OF4 WOODLAND , RED RETR...
# 39623  0.010204  (ROUND SNACK BOXES SET OF4 WOODLAND , RED RETR...
# 39624  0.010204  (ROUND SNACK BOXES SET OF4 WOODLAND , RED RETR...
# 39625  0.010204  (ROUND SNACK BOXES SET OF4 WOODLAND , RED RETR...
# 39626  0.010204  (ROUND SNACK BOXES SET OF4 WOODLAND , RED RETR...
#
# [39627 rows x 2 columns]

# %%
#Generate the Association rules based on the identified Frequent Itemsets
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets, metric="confidence",min_threshold=0.7)
rules = association_rules(frequent_itemsets, metric="confidence",min_threshold=0.75)
print(rules)
# Out:
#                                               antecedents  \
# 0                                    ( DOLLY GIRL BEAKER)
# 1                                    ( DOLLY GIRL BEAKER)
# 2                                    ( DOLLY GIRL BEAKER)
# 3                          ( I LOVE LONDON MINI BACKPACK)
# 4                          ( I LOVE LONDON MINI BACKPACK)
# ...                                                   ...
# 721430       (DOLLY GIRL CHILDRENS CUP, JUMBO BAG APPLES)
# 721431  (DOLLY GIRL CHILDRENS CUP, ALARM CLOCK BAKELIK...
# 721432  (DOLLY GIRL CHILDRENS CUP, SKULL LUNCH BOX WIT...
# 721433  (CHILDRENS CUTLERY DOLLY GIRL , SKULL LUNCH BO...
# 721434  (LUNCH BOX WITH CUTLERY RETROSPOT , DOLLY GIRL...
#
#                                               consequents  antecedent support  \
# 0                             (DOLLY GIRL CHILDRENS BOWL)            0.022959
# 1                                               (POSTAGE)            0.022959
# 2                               (SPACEBOY CHILDRENS BOWL)            0.022959
# 3                                               (POSTAGE)            0.012755
# 4                                (WOODLAND MINI BACKPACK)            0.012755
# ...                                                   ...                 ...
# 721430  (ROUND SNACK BOXES SET OF4 WOODLAND , RED RETR...            0.010204
# 721431  (ROUND SNACK BOXES SET OF4 WOODLAND , RED RETR...            0.010204
# 721432  (ROUND SNACK BOXES SET OF4 WOODLAND , RED RETR...            0.010204
# 721433  (ROUND SNACK BOXES SET OF4 WOODLAND , RED RETR...            0.012755
# 721434  (ROUND SNACK BOXES SET OF4 WOODLAND , RED RETR...            0.010204
#
#         consequent support   support  confidence       lift  leverage  \
# 0                 0.045918  0.017857    0.777778  16.938272  0.016803
# 1                 0.765306  0.017857    0.777778   1.016296  0.000286
# 2                 0.051020  0.017857    0.777778  15.244444  0.016686
# 3                 0.765306  0.010204    0.800000   1.045333  0.000443
# 4                 0.040816  0.010204    0.800000  19.600000  0.009683
# ...                    ...       ...         ...        ...       ...
# 721430            0.010204  0.010204    1.000000  98.000000  0.010100
# 721431            0.010204  0.010204    1.000000  98.000000  0.010100
# 721432            0.010204  0.010204    1.000000  98.000000  0.010100
# 721433            0.010204  0.010204    0.800000  78.400000  0.010074
# 721434            0.010204  0.010204    1.000000  98.000000  0.010100
#
#         conviction  zhangs_metric
# 0         4.293367       0.963073
# 1         1.056122       0.016412
# 2         4.270408       0.956360
# 3         1.173469       0.043928
# 4         4.795918       0.961240
# ...            ...            ...
# 721430         inf       1.000000
# 721431         inf       1.000000
# 721432         inf       1.000000
# 721433    4.948980       1.000000
# 721434         inf       1.000000
#
# [721435 rows x 10 columns]
